# %%
import pandas as pd
import string

# %% [markdown]
# Firsly, take a look at the data:

# %%
df = pd.read_csv('../data/raw/filtered.tsv', delimiter='\t', index_col=0)
df
# Out:
#                                                 reference  \
# 0       If Alkar is flooding her with psychic waste, t...
# 1                               Now you're getting nasty.
# 2                Well, we could spare your life, for one.
# 3               Ah! Monkey, you've got to snap out of it.
# 4                        I've got orders to put her down.
# ...                                                   ...
# 577772  You didn't know that Estelle had stolen some f...
# 577773                    It'il suck the life out of you!
# 577774                   I can't fuckin' take that, bruv.
# 577775  They called me a fucking hero. The truth is I ...
# 577776                               I did not screw him.
#
#                                               translation  similarity  \
# 0       if Alkar floods her with her mental waste, it ...    0.785171
# 1                             you're becoming disgusting.    0.749687
# 2                           well, we can spare your life.    0.919051
# 3                            monkey, you have to wake up.    0.664333
# 4                              I have orders to kill her.    0.726639
# ...                                                   ...         ...
# 577772  you didn't know that Estelle stole your fish f...    0.870322
# 577773                  you'd be sucked out of your life!    0.722897
# 577774                          I really can't take this.    0.617511
# 577775         they said I was a hero, but I didn't care.    0.679613
# 577776                                 I didn't fuck him.    0.868475
#
#         lenght_diff   ref_tox   trn_tox
# 0          0.010309  0.014195  0.981983
# 1          0.071429  0.065473  0.999039
# 2          0.268293  0.213313  0.985068
# 3          0.309524  0.053362  0.994215
# 4          0.181818  0.009402  0.999348
# ...             ...       ...       ...
# 577772     0.030769  0.000121  0.949143
# 577773     0.058824  0.996124  0.215794
# 577774     0.212121  0.984538  0.000049
# 577775     0.358209  0.991945  0.000124
# 577776     0.095238  0.009480  0.994174
#
# [577777 rows x 6 columns]

# %% [markdown]
# # Basic Preprocessing
#
# We will remove punctuation signs, however the meaningful apostrophe character should remain.

# %%
def basic_preprocessing(text: str) -> str:
    # remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation.replace("'", "")))
    # lowercase
    text = text.lower()
    return text

# apply basic preprocessing
for column in ['reference', 'translation']:
    df[f'{column}_processed'] = df[column].apply(basic_preprocessing)

df.sample(5)
# Out:
#                                              reference  \
# 407555  I got dominoes, and what the hell is going on?
# 454088                         You bury yours, Marcus.
# 247574                            I like your swagger.
# 98678                        We get to hang ourselves?
# 497575                                          White.
#
#                              translation  similarity  lenght_diff   ref_tox  \
# 407555   what the hell is going on here?    0.720545     0.319149  0.023868
# 454088  you're killing yourself, Marcus.    0.662741     0.272727  0.015029
# 247574                 I like your guts.    0.728945     0.142857  0.000186
# 98678             are we hanging around?    0.641338     0.115385  0.974838
# 497575                            White!    0.949085     0.000000  0.002257
#
#          trn_tox                           reference_processed  \
# 407555  0.877907  i got dominoes and what the hell is going on
# 454088  0.990032                         you bury yours marcus
# 247574  0.971967                           i like your swagger
# 98678   0.000046                      we get to hang ourselves
# 497575  0.800949                                         white
#
#                  translation_processed  \
# 407555  what the hell is going on here
# 454088  you're killing yourself marcus
# 247574                i like your guts
# 98678            are we hanging around
# 497575                           white
#
#                                                 source  \
# 407555  I got dominoes, and what the hell is going on?
# 454088                         You bury yours, Marcus.
# 247574                            I like your swagger.
# 98678                           are we hanging around?
# 497575                                          White.
#
#                                   target
# 407555   what the hell is going on here?
# 454088  you're killing yourself, Marcus.
# 247574                 I like your guts.
# 98678          We get to hang ourselves?
# 497575                            White!

# %% [markdown]
# # Source and Target disambiguation
#
# We see that the fields `reference` and `translation` are often mixed in terms of toxicity level. Let us introduce the fields `source` and `target` and distribute the samples so that `toxicity(source) > toxicity(target)`

# %%
(df.ref_tox > df.trn_tox).mean()
# Out:
# 0.5523618974102465

# %%
columns = ['reference', 'translation', 'ref_tox', 'trn_tox']
df['source'] = df[columns].apply(lambda x: x['reference'] if x['ref_tox'] > x['trn_tox'] else x['translation'], axis=1)
df['target'] = df[columns + ['source']].apply(lambda x: x['translation'] if x['source'] == x['reference'] else x['reference'], axis=1)
df.sample(5)
# Out:
#                                                 reference  \
# 220179  Let's have a toast - to the future generation ...
# 489073                  You got him in the left shoulder.
# 235042  (rapid gunfire) CALLEN: Deeks, Kensi, shooters...
# 467105  In the spring and summer they ate all the godd...
# 254415           They're smug and they are condescending.
#
#                                               translation  similarity  \
# 220179  let's toast to a new generation of consumerism...    0.637896
# 489073                        I shot him in the shoulder.    0.623977
# 235042         Deeks, Kensi, shooters are going your way!    0.773226
# 467105  they ate all the flowers in the spring and sum...    0.887404
# 254415                     they're arrogant and arrogant.    0.654547
#
#         lenght_diff   ref_tox   trn_tox  \
# 220179     0.057692  0.995674  0.000467
# 489073     0.176471  0.004725  0.982798
# 235042     0.328125  0.029150  0.718189
# 467105     0.116667  0.999108  0.000071
# 254415     0.243902  0.076535  0.998256
#
#                                                    source  \
# 220179  Let's have a toast - to the future generation ...
# 489073                        I shot him in the shoulder.
# 235042         Deeks, Kensi, shooters are going your way!
# 467105  In the spring and summer they ate all the godd...
# 254415                     they're arrogant and arrogant.
#
#                                                    target
# 220179  let's toast to a new generation of consumerism...
# 489073                  You got him in the left shoulder.
# 235042  (rapid gunfire) CALLEN: Deeks, Kensi, shooters...
# 467105  they ate all the flowers in the spring and sum...
# 254415           They're smug and they are condescending.

# %% [markdown]
# ## Save the data (to /src later)

# %%
df.to_csv('../data/interim/distinguished.tsv', sep='\t', index=False)

# %%
df_dvizh = pd.read_csv('../data/interim/distinguished.tsv', delimiter='\t')
df_dvizh
# Out:
#                                                 reference  \
# 0       If Alkar is flooding her with psychic waste, t...
# 1                               Now you're getting nasty.
# 2                Well, we could spare your life, for one.
# 3               Ah! Monkey, you've got to snap out of it.
# 4                        I've got orders to put her down.
# ...                                                   ...
# 577772  You didn't know that Estelle had stolen some f...
# 577773                    It'il suck the life out of you!
# 577774                   I can't fuckin' take that, bruv.
# 577775  They called me a fucking hero. The truth is I ...
# 577776                               I did not screw him.
#
#                                               translation  similarity  \
# 0       if Alkar floods her with her mental waste, it ...    0.785171
# 1                             you're becoming disgusting.    0.749687
# 2                           well, we can spare your life.    0.919051
# 3                            monkey, you have to wake up.    0.664333
# 4                              I have orders to kill her.    0.726639
# ...                                                   ...         ...
# 577772  you didn't know that Estelle stole your fish f...    0.870322
# 577773                  you'd be sucked out of your life!    0.722897
# 577774                          I really can't take this.    0.617511
# 577775         they said I was a hero, but I didn't care.    0.679613
# 577776                                 I didn't fuck him.    0.868475
#
#         lenght_diff   ref_tox   trn_tox  \
# 0          0.010309  0.014195  0.981983
# 1          0.071429  0.065473  0.999039
# 2          0.268293  0.213313  0.985068
# 3          0.309524  0.053362  0.994215
# 4          0.181818  0.009402  0.999348
# ...             ...       ...       ...
# 577772     0.030769  0.000121  0.949143
# 577773     0.058824  0.996124  0.215794
# 577774     0.212121  0.984538  0.000049
# 577775     0.358209  0.991945  0.000124
# 577776     0.095238  0.009480  0.994174
#
#                                                    source  \
# 0       if Alkar floods her with her mental waste, it ...
# 1                             you're becoming disgusting.
# 2                           well, we can spare your life.
# 3                            monkey, you have to wake up.
# 4                              I have orders to kill her.
# ...                                                   ...
# 577772  you didn't know that Estelle stole your fish f...
# 577773                    It'il suck the life out of you!
# 577774                   I can't fuckin' take that, bruv.
# 577775  They called me a fucking hero. The truth is I ...
# 577776                                 I didn't fuck him.
#
#                                                    target
# 0       If Alkar is flooding her with psychic waste, t...
# 1                               Now you're getting nasty.
# 2                Well, we could spare your life, for one.
# 3               Ah! Monkey, you've got to snap out of it.
# 4                        I've got orders to put her down.
# ...                                                   ...
# 577772  You didn't know that Estelle had stolen some f...
# 577773                  you'd be sucked out of your life!
# 577774                          I really can't take this.
# 577775         they said I was a hero, but I didn't care.
# 577776                               I did not screw him.
#
# [577777 rows x 8 columns]
