# %%
import pandas as pd
import string

# %% [markdown]
# Firsly, take a look at the data:

# %%
df = pd.read_csv('../data/raw/filtered.tsv', delimiter='\t', index_col=0)
df
# Out:
#                                                 reference  \
# 0       If Alkar is flooding her with psychic waste, t...
# 1                               Now you're getting nasty.
# 2                Well, we could spare your life, for one.
# 3               Ah! Monkey, you've got to snap out of it.
# 4                        I've got orders to put her down.
# ...                                                   ...
# 577772  You didn't know that Estelle had stolen some f...
# 577773                    It'il suck the life out of you!
# 577774                   I can't fuckin' take that, bruv.
# 577775  They called me a fucking hero. The truth is I ...
# 577776                               I did not screw him.
#
#                                               translation  similarity  \
# 0       if Alkar floods her with her mental waste, it ...    0.785171
# 1                             you're becoming disgusting.    0.749687
# ...

# %%
df.loc[577745]['reference']
# Out:
# "I'm going to hit you in all directions, civil and criminal, on all counts."

# %% [markdown]
# Let us apply the basic text preprocessing.
#
# We will remove punctuation signs, however the meaningful ones should remain. They are `'`

# %%
df[df['reference'].str.contains(r'\$')]
# Out:
#                                                 reference  \
# 541     Today, a delicious hot dog will cost you $2.50...
# 1953    (Distorted) Bring $2 million in hundreds to Ch...
# 3243    And when you turn all the rest of this shit in...
# 3815    Or you could get the $40,000-a-year... court-a...
# 3970       He offered me $5,000 to have sex with him. Hi.
# ...                                                   ...
# 576881  Listen, for $100K... I can be your practice pa...
# 576920  I'm serious. I’m not kidding. $13,000 in some ...
# 577241    Whoever turns this traitor in receives $10,000.
# 577496   I was screwing guys for a bag of dope, Dad. $10.
# 577505         What good's your $15 million now, asshole?
#
#                                               translation  similarity  \
# 541     you're gonna have a hot dog for $2.50 today, b...    0.805166
# 1953    in three hours you bring $2 million to the cor...    0.852156
# ...

# %%
string.punctuation.replace("'", "")
# Out:
# '!"#$%&()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def basic_preprocessing(text: str) -> str:
    # remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation.replace("'", "")))
    # lowercase
    text = text.lower()
    return text

# apply basic preprocessing
for column in ['reference', 'translation']:
    df[f'{column}_processed'] = df[column].apply(basic_preprocessing)

df
# Out:
#         Unnamed: 0                                          reference  \
# 0                0  If Alkar is flooding her with psychic waste, t...
# 1                1                          Now you're getting nasty.
# 2                2           Well, we could spare your life, for one.
# 3                3          Ah! Monkey, you've got to snap out of it.
# 4                4                   I've got orders to put her down.
# ...            ...                                                ...
# 577772      577772  You didn't know that Estelle had stolen some f...
# 577773      577773                    It'il suck the life out of you!
# 577774      577774                   I can't fuckin' take that, bruv.
# 577775      577775  They called me a fucking hero. The truth is I ...
# 577776      577776                               I did not screw him.
#
#                                               translation  similarity  \
# ...
